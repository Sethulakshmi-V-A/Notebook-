# %% [markdown]
# ### ICT CLASS ACTIVITY

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
adv_data=pd.read_csv(r"C:\Users\hp\Downloads\Advertising.csv")
adv_data
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %% [markdown]
# ## 1. Explain the dataset

# %%
adv_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
adv_data.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %% [markdown]
# Inference: There are no null values in the set.

# %%
adv_data.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %% [markdown]
# #### * The figure below shows the spread of sales  with respect to spendings on TV and Newspaper advertisements.

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(adv_data['TV'],adv_data['Newspaper'],hue=adv_data['Sales'],palette='magma_r')
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TV', ylabel='Newspaper'>

# %% [markdown]
# ### Inference:
# 1) Even for less Newspaper spending on advertisements there has been significant high sales.
#
# 2) Spending on TV advertisements has significant effect on increase of sales.

# %% [markdown]
# #### * To find the pattern in the variation in  spending on three advertisements in the first 50 observations on sales in the decreasing and increasing order

# %%
adv_data=adv_data.drop(['Unnamed: 0'],axis=1) # To drop the column 'unnamed' which indicates the serial number of the observation 
adv_data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
data1=adv_data.sort_values(['Sales'],ascending=False)
data1 # gives data in the decreasing values of sales
# Out:
#         TV  Radio  Newspaper  Sales
# 175  276.9   48.9       41.8   27.0
# 183  287.6   43.0       71.8   26.2
# 198  283.6   42.0       66.2   25.5
# 98   289.7   42.3       51.2   25.4
# 147  243.2   49.0       44.3   25.4
# ..     ...    ...        ...    ...
# 108   13.1    0.4       25.6    5.3
# 78     5.4   29.9        9.4    5.3
# 8      8.6    2.1        1.0    4.8
# 155    4.1   11.6        5.7    3.2
# 130    0.7   39.6        8.7    1.6
#
# [200 rows x 4 columns]

# %%
data1=data1.head(50)
data1
# Out:
#         TV  Radio  Newspaper  Sales
# 175  276.9   48.9       41.8   27.0
# 183  287.6   43.0       71.8   26.2
# 198  283.6   42.0       66.2   25.5
# 98   289.7   42.3       51.2   25.4
# 147  243.2   49.0       44.3   25.4
# 36   266.9   43.8        5.0   25.4
# 128  220.3   49.0        3.2   24.7
# 17   281.4   39.6       55.8   24.4
# 61   261.3   42.7       54.7   24.2
# 101  296.4   36.3      100.9   23.8
# 58   210.8   49.6       37.7   23.8
# 55   198.9   49.4       60.0   23.7
# 47   239.9   41.5       18.5   23.2
# 52   216.4   41.7       39.6   22.6
# 185  205.0   45.1       19.6   22.6
# 15   195.4   47.7       52.9   22.4
# 69   216.8   43.9       27.2   22.3
# 93   250.9   36.5       72.3   22.2
# 0    230.1   37.8       69.2   22.1
# 111  241.7   38.0       23.2   21.8
# 84   213.5   43.0       33.8   21.7
# 39   228.0   37.7       32.0   21.5
# 30   292.9   28.3       43.2   21.4
# 53   182.6   46.2       58.7   21.2
# 137  273.7   28.9       59.7   20.8
# ...

# %%
data2=adv_data.sort_values(['Sales'],ascending=True) 
data2 # gives data in the increasing order of sales
# Out:
#         TV  Radio  Newspaper  Sales
# 130    0.7   39.6        8.7    1.6
# 155    4.1   11.6        5.7    3.2
# 8      8.6    2.1        1.0    4.8
# 108   13.1    0.4       25.6    5.3
# 78     5.4   29.9        9.4    5.3
# ..     ...    ...        ...    ...
# 98   289.7   42.3       51.2   25.4
# 147  243.2   49.0       44.3   25.4
# 198  283.6   42.0       66.2   25.5
# 183  287.6   43.0       71.8   26.2
# 175  276.9   48.9       41.8   27.0
#
# [200 rows x 4 columns]

# %%
data2=data2.head(50)
data2
# Out:
#         TV  Radio  Newspaper  Sales
# 130    0.7   39.6        8.7    1.6
# 155    4.1   11.6        5.7    3.2
# 8      8.6    2.1        1.0    4.8
# 108   13.1    0.4       25.6    5.3
# 78     5.4   29.9        9.4    5.3
# 56     7.3   28.1       41.4    5.5
# 22    13.2   15.9       49.6    5.6
# 132    8.4   27.2        2.1    5.7
# 192   17.2    4.1       31.6    5.9
# 119   19.4   16.0       22.3    6.6
# 126    7.8   38.9       50.6    6.6
# 189   18.7   12.1       23.4    6.7
# 76    27.5    1.6       20.7    6.9
# 121   18.8   21.7       50.4    7.0
# 5      8.7   48.9       75.0    7.2
# 106   25.0   11.0       29.7    7.2
# 91    28.6    1.5       33.0    7.3
# 158   11.7   36.9       45.2    7.3
# 195   38.2    3.7       13.8    7.6
# 172   19.6   20.1       17.0    7.6
# 166   17.9   37.6       21.6    8.0
# 60    53.5    2.0       21.4    8.1
# 170   50.0   11.6       18.4    8.4
# 44    25.1   25.7       43.3    8.5
# 10    66.1    5.8       24.2    8.6
# ...

# %%
fig=plt.figure(figsize=(8,8))
ax1 = fig.add_subplot(111)
ax1.scatter(data1['TV'],data1['Radio'],label='high sale')
ax1.scatter(data2['TV'],data2['Radio'],label='low sale')
plt.legend(loc='upper left')
plt.title('Relation between TV and Radio advertising when the sale is very high and very low',fontsize=20)
plt.xlabel('TV',fontsize=15)
plt.ylabel('Radio',fontsize=15)
plt.show()

# %% [markdown]
# ### Inference:
# 1)Higher spending on TV and Radio advertisements results in higher sales.
#
# 2)A clear distinction can be made between lower and higher sales based on spendings on TV and Radio advertisements.

# %%
fig=plt.figure(figsize=(8,8))
ax2 = fig.add_subplot(111)
ax2.scatter(data1['TV'],data1['Newspaper'],label='high sale',color='black')
ax2.scatter(data2['TV'],data2['Newspaper'],label='low sale',color='blue')
plt.title('Relation between TV and Newspaper advertising when the sale is very high and very low',fontsize=20)
plt.xlabel('TV',fontsize=15)
plt.ylabel('Newspaper',fontsize=15)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# # Inference:
# 1) A clear distiction can be made between high and low sales based on spending in TV advertisements.Higher the spending on TV advertisements sales increases.
#
# 2) Newspaper spending doesn't have any significant effect on increase in sales

# %%
fig=plt.figure(figsize=(8,8))
ax3 = fig.add_subplot(111)
ax3.scatter(data1['Newspaper'],data1['Radio'],label='high',color='red')
ax3.scatter(data2['Newspaper'],data2['Radio'],label='low',color='orange')
plt.title('Relation between  Newspaper and Radio advertising when the sale is very high and very low',fontsize=20)
plt.xlabel('Newspaper',fontsize=15)
plt.ylabel('Radio',fontsize=15)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# # Inference:
# 1) High sales have high spending on Radio advertisements.
#
# 2) Newspaper spending has mixed results, lower sales and higher sales.

# %% [markdown]
# #### * The figure below checks the linearity relationship between three advertisement media and sales.

# %%
plt.figure(figsize=(10,20))
plt.subplot(311)
sns.regplot(x='TV',y='Sales',data=adv_data,scatter_kws={'color':'orange'},line_kws={'color':'black'})
plt.title('Relation between TV advertising and Sales',fontsize=18)
plt.xlabel('TV',fontsize=15)
plt.ylabel('Sales',fontsize=15)

plt.subplot(312)
sns.regplot(x='Newspaper',y='Sales',data=adv_data,scatter_kws={'color':'red'},line_kws={'color':'black'})
plt.title('Relation between Newspaper advertising and Sales',fontsize=18)
plt.xlabel('Newspaper',fontsize=15)
plt.ylabel('Sales',fontsize=15)

plt.subplot(313)
sns.regplot(x='Radio',y='Sales',data=adv_data,scatter_kws={'color':'green'},line_kws={'color':'blue'})
plt.title('Relation between Radio advertising and Sales',fontsize=18)
plt.xlabel('Radio',fontsize=15)
plt.ylabel('Sales',fontsize=15)
# Out:
# Text(0, 0.5, 'Sales')

# %% [markdown]
# ### Inference:
# 1)Spending on Tv advertisements has a large  linear relationship with sales compared to the other spendings.
#
# 2)Newspaper advertisements show the least or no linearity effect on sales.

# %% [markdown]
# #### 2. Check the summary statistics and discuss the max, min, avg, median, and percentiles.

# %%
adv_data.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# ##### Inference:
# 1) The average spending on TV advertisements is more compared to the Radio and Newspaper advertisements.
#
# 2) The spending on radio was once nil and hasn't crossed above 50.00 units of amount compared to the other spending.

# %% [markdown]
# ####  3. The manager wants to find out whether the same amount was spent for the three advertisements (TV , Radio and Newspaper).     Comment on your findings.

# %% [markdown]
# In order to check whether same amount was spent on the advertisements we can compare the equality of means of the three advertisements.This can be done using the ANOVA.
#
# Consider the hypothesis
#
# H0 : Same amounts were spent for three advertisements
# H1 : Different amounts were spent for the advertisements

# %%
from scipy.stats import f_oneway

# %%
f_val,p_val=f_oneway(adv_data['TV'],adv_data['Radio'],adv_data['Newspaper'])
print('F value:',f_val,'\nP value:',p_val)
# Out:
# F value: 358.8514595342597
# P value: 4.552931539744962e-103

# %%
alpha=0.05
if p_val>= alpha:
    print('Sample fails to reject null hypotheses.','\n Same amounts were spent for the three advertisements.')
else:
     print('Sample fails to accept null hypothesis.','\n Different amounts were spent for the three advertisements.')
# Out:
# Sample fails to accept null hypothesis.
#  Different amounts were spent for the three advertisements.
